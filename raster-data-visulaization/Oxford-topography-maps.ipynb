# %% [markdown]
# <a href="https://colab.research.google.com/github/sscheuern1-art/gis-project-portfolio-geo441/blob/main/raster-data-visulaization/Oxford-topography-maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Raster Data Terrain Analysis**

# %% [markdown]
# Created by Sarah Scheuern
#
# 10/28/2025

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ## **Part 1: Oxford Topography Map**

# %% [markdown]
# Below is a map of Oxford, Ohio's topography, prepared following the [Week 9 Assignment Guide](https://docs.google.com/document/d/1DT_0BKPsmqB9xtcc6IAaj-AdU21O1fyvQZhNYV6DipQ/edit?usp=sharing).
#
#
# <mark>Insert the map below:</mark>
#
#
# [Oxford Ohio Topography](https://drive.google.com/file/d/1HAa5QrY49IPVxV0bxWeLeB5nwDXaEBCu/view?usp=sharing)
#
# ![Oxford Ohio Topography](https://drive.google.com/uc?export=view&id=1HAa5QrY49IPVxV0bxWeLeB5nwDXaEBCu)

# %% [markdown]
# ## **Part 2: Oxford Zonal Statistics Map**

# %% [markdown]
# Below is a map of Oxford, Ohio's parcels visualized by average slope, prepared following the [Week 9 Assignment Guide](https://docs.google.com/document/d/1DT_0BKPsmqB9xtcc6IAaj-AdU21O1fyvQZhNYV6DipQ/edit?usp=sharing).
#
#
#
# <mark>Insert the map below:</mark>
#
# [Oxford Ohio Parcel Slopes](https://drive.google.com/file/d/12SgsVrvz40RCfirKn7Yd3ZBR9UoSFJpj/view?usp=sharing)
#
# ![Oxford Ohio Parcel Slopes](https://drive.google.com/uc?export=view&id=12SgsVrvz40RCfirKn7Yd3ZBR9UoSFJpj)

# %% [markdown]
# ## **Part 3: Reflection**
#
# *In a brief paragraph, compare the two maps you created. Describe the visual and data model differences between the DEM datasets visualized in the topology map and the zonal statistics calculated and appended to the parcel dataset in the second map.*
#
#
# The first map, the DEM dataset visualized is continuous with color values changing gradually as the elevations change. The second map, the zonal statistics, is broken into discrete values where different colors represent different ranges. Although they both demonstrate changing elevations, the first one does so in a raster way gradually changing color with the elevation. The second image does so in a vector way with polygons representing parcels slope.

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure that your images are all rendering and then share the notebook so that it is viewable by anyone with the link.
#
# <mark>**Submit the shareable link to Canvas for the Week 9 Assignment.**</mark>
